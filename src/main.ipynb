# %%
import win32com.client

# %%
cybos = win32com.client.Dispatch('CpUtil.CpCybos')
code = win32com.client.Dispatch('CpUtil.CpStockCode')

# %%
count = code.GetCount()
print('count: ', count)
# Out:
# count:  3617

# %%
for i in range(count):
    data = code.GetData(1, i)
    print(i, 'th data: ', data)
# Out:
# 0 th data:  동화약품
# 1 th data:  KR모터스
# 2 th data:  경방
# 3 th data:  메리츠화재
# 4 th data:  삼양홀딩스
# 5 th data:  삼양홀딩스우
# 6 th data:  하이트진로
# 7 th data:  하이트진로2우B
# 8 th data:  유한양행
# 9 th data:  유한양행우
# 10 th data:  CJ대한통운
# 11 th data:  하이트진로홀딩스
# 12 th data:  하이트진로홀딩스우
# 13 th data:  두산
# 14 th data:  두산우
# 15 th data:  두산2우B
# 16 th data:  성창기업지주
# 17 th data:  DL
# 18 th data:  DL우
# 19 th data:  유유제약
# 20 th data:  유유제약1우
# 21 th data:  유유제약2우B
# 22 th data:  일동홀딩스
# 23 th data:  한국앤컴퍼니
# 24 th data:  삼천당제약
# 25 th data:  기아
# 26 th data:  대유플러스
# 27 th data:  노루홀딩스
# 28 th data:  노루홀딩스우
# 29 th data:  한화손해보험
# 30 th data:  삼화페인트
# 31 th data:  롯데손해보험
# 32 th data:  대원강업
# 33 th data:  중앙에너비스
# 34 th data:  조선내화
# 35 th data:  대동
# 36 th data:  가온전선
# 37 th data:  삼일제약
# 38 th data:  흥국화재
# 39 th data:  흥국화재우
# 40 th data:  흥국화재2우B
# 41 th data:  CS홀딩스
# 42 th data:  동아쏘시오홀딩스
# 43 th data:  천일고속
# 44 th data:  SK하이닉스
# 45 th data:  영풍
# 46 th data:  LS네트웍스
# 47 th data:  유수홀딩스
# ...
